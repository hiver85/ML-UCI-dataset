# %%
import csv
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
sns.set(color_codes=True)

# %%
data = []
targets = []
abalone = []

features = ["sex", "length", "diameter", "height", "whole weight", 
                "shucked weight", "viscera weight", "shell weight", "rings"]


#abln = pd.read_csv("C:/Users/lenovo/Google Drive/PHAP/2IS/Semestre2/CI/PRJ1/Data/abalone.data", sep=',', 
#                  names = ["sex", "length", "diameter", "height", "whole weight", 
#                "shucked weight", "viscera weight", "shell weight", "rings"])

# %%
with open("C:/Users/lenovo/Google Drive/PHAP/2IS/Semestre2/CI/PRJ1/Data/abalone.data", newline='') as csvfile:
    abalonereader = csv.reader(csvfile, delimiter=',')
    for row in abalonereader:
        #print(row)
        if row[0] == "M":
            row[0] = 1
        if row[0] == "F":
            row[0] = 2
        if row[0] == "I":
            row[0] = 3
        for i in range(1, 7):
            row[i] = float(row[i])
        data.append(row[:7])
        abalone.append(row[:8])
        targets.append(float(row[8]))

data = np.array(data)
targets = np.array(targets)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
sns.set_style("whitegrid")

df = pd.DataFrame(abln)

plot = sns.swarmplot(x="shell weight", y="rings", hue="sex", data=df);
fig.savefig("swarmplotabln.png")

# %%
plot = sns.pairplot(df, hue = "sex", size=2.5)
fig.savefig("pairplot1.png")

# %%
plt.figure(figsize=(10,10))
correlation = df.corr()
sns.heatmap(correlation, square=True,annot=True,vmin=0,vmax=1,cmap='jet')
plt.title('Correlation Matrix (Unscaled Variables)')
plt.show()
fig.savefig('pairplot.png')


df = pd.DataFrame(abln)
sns.set(style="ticks")

# Load the example tips dataset

# Draw a nested boxplot to show bills by day and sex
plot = sns.boxplot(x="sex", y="rings",  data=df, palette="PRGn")
sns.despine(offset=10, trim=True)
#lot.savefig("boxplot.png")
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-5c4e686d0a5f> in <module>()
#      15 plot = sns.boxplot(x="sex", y="rings",  data=df, palette="PRGn")
#      16 sns.despine(offset=10, trim=True)
# ---> 17 plot.savefig("boxplot.png")
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
plt.figure(figsize=(10,10))
correlation = df.corr()
sns.heatmap(correlation, square=True,annot=True,vmin=0,vmax=1,cmap='jet')
plt.title('Correlation Matrix (Unscaled Variables)')
plt.show()
sns.swarmplot(x="shell weight", y="rings", hue="sex", data=df, ax=ax);
sns.despine()
fig.savefig('example.png')

# %%
plt.figure(figsize=(30,30))
for i in range(7):
    
    plt.figure(figsize=(40,30))
    plt.subplot(5, 5, i + 1)
    plt.scatter(data[:, i], targets, edgecolors=(0, 0, 0));
    plt.title('Feature: %s' % features[i])
    plt.show()
